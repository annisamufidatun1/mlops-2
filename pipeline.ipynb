# %%
# import lib
import os
import sys
from typing import Text

from absl import logging
from tfx.orchestration import metadata, pipeline
from tfx.orchestration.beam.beam_dag_runner import BeamDagRunner
from modules import components

# %%
DATA_ROOT = "data"
PIPELINE_NAME = "annisams11-pipeline"

TRANSFORM_MODULE_FILE = "modules/stroke_pred_transform.py"
TUNER_MODULE_FILE = "modules/stroke_pred_tuner.py"
TRAINER_MODULE_FILE = "modules/stroke_pred_trainer.py"

OUTPUT_BASE = "outputs"
serving_model_dir = os.path.join(OUTPUT_BASE, 'serving_model')
pipeline_root = os.path.join(OUTPUT_BASE, PIPELINE_NAME)
metadata_path = os.path.join(pipeline_root, "metadata.sqlite")

# %%
def init_local_pipeline(
    components, pipeline_root: Text
) -> pipeline.Pipeline:
    """Init local pipeline

    Args:
        components (dict): tfx components
        pipeline_root (Text): path to pipeline directory

    Returns:
        pipeline.Pipeline: apache beam pipeline orchestration
    """
    logging.info(f"Pipeline root set to: {pipeline_root}")
    beam_args = [
        '--direct_running_mode=multi_processing'
        # 0 auto-detect based on on the number of CPUs available
        # during execution time.
        '----direct_num_workers=0'
    ]

    return pipeline.Pipeline(
        pipeline_name=PIPELINE_NAME,
        pipeline_root=pipeline_root,
        components=components,
        enable_cache=True,
        metadata_connection_config=metadata.sqlite_metadata_connection_config(
            metadata_path
        ),
        eam_pipeline_args=beam_args
    )

logging.set_verbosity(logging.INFO)

components = components.init_components({
    'data_dir': DATA_ROOT,
    'transform_module': TRANSFORM_MODULE_FILE,
    'tuner_module': TUNER_MODULE_FILE,
    'training_module': TRAINER_MODULE_FILE,
    'training_steps': 5000,
    'eval_steps': 1000,
    'serving_model_dir': serving_model_dir
})

pipeline = init_local_pipeline(components, pipeline_root)
BeamDagRunner().run(pipeline=pipeline)
# Out:
# Trial 2 Complete [00h 00m 16s]
# val_binary_accuracy: 0.9593999981880188
#
# Best val_binary_accuracy So Far: 0.9611999988555908
# Total elapsed time: 00h 00m 31s
# INFO:tensorflow:Oracle triggered exit
# INFO:tensorflow:Oracle triggered exit
# INFO:absl:Finished tuning... Tuner ID: tuner0
# INFO:absl:Best HyperParameters: {'space': [{'class_name': 'Choice', 'config': {'name': 'units_1', 'default': 128, 'conditions': [], 'values': [128, 256, 512], 'ordered': True}}, {'class_name': 'Choice', 'config': {'name': 'units_2', 'default': 32, 'conditions': [], 'values': [32, 64, 128], 'ordered': True}}, {'class_name': 'Choice', 'config': {'name': 'units_3', 'default': 8, 'conditions': [], 'values': [8, 16, 32], 'ordered': True}}, {'class_name': 'Choice', 'config': {'name': 'learning_rate', 'default': 0.01, 'conditions': [], 'values': [0.01, 0.001, 0.0001], 'ordered': True}}], 'values': {'units_1': 256, 'units_2': 128, 'units_3': 16, 'learning_rate': 0.01}}
# INFO:absl:Best Hyperparameters are written to output\annisams11-pipeline\Tuner\best_hyperparameters\15\best_hyperparameters.txt.
# INFO:absl:Tuner results are written to output\annisams11-pipeline\Tuner\tuner_results\15\tuner_results.json.
# INFO:absl:Cleaning up stateless execution info.
# INFO:absl:Execution 15 succeeded.
# INFO:absl:Cleaning up stateful execution info.
# INFO:absl:Publishing output artifacts defaultdict(<class 'list'>, {'tuner_results': [Artifact(artifact: uri: "output\\annisams11-pipeline\\Tuner\\tuner_results\\15"
# , artifact_type: name: "TunerResults"
# )], 'best_hyperparameters': [Artifact(artifact: uri: "output\\annisams11-pipeline\\Tuner\\best_hyperparameters\\15"
# , artifact_type: name: "HyperParameters"
# )]}) for execution 15
# INFO:absl:MetadataStore with DB connection initialized
# INFO:absl:node Tuner is finished.
# INFO:absl:node Trainer is running.
# INFO:absl:Running launcher for node_info {
#   type {
#     name: "tfx.components.trainer.component.Trainer"
#     base_type: TRAIN
#   }
#   id: "Trainer"
# }
# contexts {
#   contexts {
#     type {
#       name: "pipeline"
#     }
#     name {
#       field_value {
#         string_value: "annisams11-pipeline"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "pipeline_run"
#     }
#     name {
#       field_value {
#         string_value: "20240720-154120.432064"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "node"
#     }
#     name {
#       field_value {
#         string_value: "annisams11-pipeline.Trainer"
#       }
#     }
#   }
# }
# inputs {
#   inputs {
#     key: "examples"
#     value {
#       channels {
#         producer_node_query {
#           id: "Transform"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "annisams11-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20240720-154120.432064"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "annisams11-pipeline.Transform"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "Examples"
#             base_type: DATASET
#           }
#         }
#         output_key: "transformed_examples"
#       }
#       min_count: 1
#     }
#   }
#   inputs {
#     key: "hyperparameters"
#     value {
#       channels {
#         producer_node_query {
#           id: "Tuner"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "annisams11-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20240720-154120.432064"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "annisams11-pipeline.Tuner"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "HyperParameters"
#           }
#         }
#         output_key: "best_hyperparameters"
#       }
#     }
#   }
#   inputs {
#     key: "schema"
#     value {
#       channels {
#         producer_node_query {
#           id: "SchemaGen"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "annisams11-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20240720-154120.432064"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "annisams11-pipeline.SchemaGen"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "Schema"
#           }
#         }
#         output_key: "schema"
#       }
#     }
#   }
#   inputs {
#     key: "transform_graph"
#     value {
#       channels {
#         producer_node_query {
#           id: "Transform"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "annisams11-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20240720-154120.432064"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "annisams11-pipeline.Transform"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "TransformGraph"
#           }
#         }
#         output_key: "transform_graph"
#       }
#     }
#   }
# }
# outputs {
#   outputs {
#     key: "model"
#     value {
#       artifact_spec {
#         type {
#           name: "Model"
#           base_type: MODEL
#         }
#       }
#     }
#   }
#   outputs {
#     key: "model_run"
#     value {
#       artifact_spec {
#         type {
#           name: "ModelRun"
#         }
#       }
#     }
#   }
# }
# parameters {
#   parameters {
#     key: "custom_config"
#     value {
#       field_value {
#         string_value: "null"
#       }
#     }
#   }
#   parameters {
#     key: "eval_args"
#     value {
#       field_value {
#         string_value: "{\n  \"num_steps\": 1000,\n  \"splits\": [\n    \"eval\"\n  ]\n}"
#       }
#     }
#   }
#   parameters {
#     key: "module_path"
#     value {
#       field_value {
#         string_value: "stroke_pred_trainer@output\\annisams11-pipeline\\_wheels\\tfx_user_code_Trainer-0.0+c9842627d14a7260429e87a5ee0bbb6a28ca35a48a05d0344e6aa6eeb4a3cc2f-py3-none-any.whl"
#       }
#     }
#   }
#   parameters {
#     key: "train_args"
#     value {
#       field_value {
#         string_value: "{\n  \"num_steps\": 5000,\n  \"splits\": [\n    \"train\"\n  ]\n}"
#       }
#     }
#   }
# }
# upstream_nodes: "SchemaGen"
# upstream_nodes: "Transform"
# upstream_nodes: "Tuner"
# downstream_nodes: "Evaluator"
# downstream_nodes: "Pusher"
# execution_options {
#   caching_options {
#     enable_cache: true
#   }
# }
#
# INFO:absl:MetadataStore with DB connection initialized
# WARNING:absl:ArtifactQuery.property_predicate is not supported.
# Results summary
# Results in output\annisams11-pipeline\Tuner\.system\executor_execution\15\.temp\15\stroke_pred_tuning
# Showing 10 best trials
# <keras_tuner.engine.objective.Objective object at 0x0000016BAC9CC340>
# Trial summary
# Hyperparameters:
# units_1: 256
# units_2: 128
# units_3: 16
# learning_rate: 0.01
# Score: 0.9611999988555908
# Trial summary
# Hyperparameters:
# units_1: 512
# units_2: 32
# units_3: 8
# learning_rate: 0.0001
# Score: 0.9593999981880188
# WARNING:absl:ArtifactQuery.property_predicate is not supported.
# WARNING:absl:ArtifactQuery.property_predicate is not supported.
# WARNING:absl:ArtifactQuery.property_predicate is not supported.
# INFO:absl:[Trainer] Resolved inputs: ({'schema': [Artifact(artifact: id: 3
# type_id: 20
# uri: "output\\annisams11-pipeline\\SchemaGen\\schema\\4"
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1721464533068
# last_update_time_since_epoch: 1721464533068
# , artifact_type: id: 20
# name: "Schema"
# )], 'examples': [Artifact(artifact: id: 17
# type_id: 16
# uri: "output\\annisams11-pipeline\\Transform\\transformed_examples\\13"
# properties {
#   key: "split_names"
#   value {
#     string_value: "[\"eval\", \"train\"]"
#   }
# }
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1721464916761
# last_update_time_since_epoch: 1721464916761
# , artifact_type: id: 16
# name: "Examples"
# properties {
#   key: "span"
#   value: INT
# }
# properties {
#   key: "split_names"
#   value: STRING
# }
# properties {
#   key: "version"
#   value: INT
# }
# base_type: DATASET
# )], 'hyperparameters': [Artifact(artifact: id: 24
# type_id: 27
# uri: "output\\annisams11-pipeline\\Tuner\\best_hyperparameters\\15"
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1721464951036
# last_update_time_since_epoch: 1721464951036
# , artifact_type: id: 27
# name: "HyperParameters"
# )], 'transform_graph': [Artifact(artifact: id: 15
# type_id: 22
# uri: "output\\annisams11-pipeline\\Transform\\transform_graph\\13"
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1721464916760
# last_update_time_since_epoch: 1721464916760
# , artifact_type: id: 22
# name: "TransformGraph"
# )]},)
# INFO:absl:MetadataStore with DB connection initialized
# INFO:absl:Going to run a new execution 16
# INFO:absl:Going to run a new execution: ExecutionInfo(execution_id=16, input_dict={'schema': [Artifact(artifact: id: 3
# type_id: 20
# uri: "output\\annisams11-pipeline\\SchemaGen\\schema\\4"
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1721464533068
# last_update_time_since_epoch: 1721464533068
# , artifact_type: id: 20
# name: "Schema"
# )], 'examples': [Artifact(artifact: id: 17
# type_id: 16
# uri: "output\\annisams11-pipeline\\Transform\\transformed_examples\\13"
# properties {
#   key: "split_names"
#   value {
#     string_value: "[\"eval\", \"train\"]"
#   }
# }
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1721464916761
# last_update_time_since_epoch: 1721464916761
# , artifact_type: id: 16
# name: "Examples"
# properties {
#   key: "span"
#   value: INT
# }
# properties {
#   key: "split_names"
#   value: STRING
# }
# properties {
#   key: "version"
#   value: INT
# }
# base_type: DATASET
# )], 'hyperparameters': [Artifact(artifact: id: 24
# type_id: 27
# uri: "output\\annisams11-pipeline\\Tuner\\best_hyperparameters\\15"
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1721464951036
# last_update_time_since_epoch: 1721464951036
# , artifact_type: id: 27
# name: "HyperParameters"
# )], 'transform_graph': [Artifact(artifact: id: 15
# type_id: 22
# uri: "output\\annisams11-pipeline\\Transform\\transform_graph\\13"
# custom_properties {
#   key: "is_external"
#   value {
#     int_value: 0
#   }
# }
# custom_properties {
#   key: "state"
#   value {
#     string_value: "published"
#   }
# }
# custom_properties {
#   key: "tfx_version"
#   value {
#     string_value: "1.11.0"
#   }
# }
# state: LIVE
# create_time_since_epoch: 1721464916760
# last_update_time_since_epoch: 1721464916760
# , artifact_type: id: 22
# name: "TransformGraph"
# )]}, output_dict=defaultdict(<class 'list'>, {'model': [Artifact(artifact: uri: "output\\annisams11-pipeline\\Trainer\\model\\16"
# , artifact_type: name: "Model"
# base_type: MODEL
# )], 'model_run': [Artifact(artifact: uri: "output\\annisams11-pipeline\\Trainer\\model_run\\16"
# , artifact_type: name: "ModelRun"
# )]}), exec_properties={'custom_config': 'null', 'eval_args': '{\n  "num_steps": 1000,\n  "splits": [\n    "eval"\n  ]\n}', 'train_args': '{\n  "num_steps": 5000,\n  "splits": [\n    "train"\n  ]\n}', 'module_path': 'stroke_pred_trainer@output\\annisams11-pipeline\\_wheels\\tfx_user_code_Trainer-0.0+c9842627d14a7260429e87a5ee0bbb6a28ca35a48a05d0344e6aa6eeb4a3cc2f-py3-none-any.whl'}, execution_output_uri='output\\annisams11-pipeline\\Trainer\\.system\\executor_execution\\16\\executor_output.pb', stateful_working_dir='output\\annisams11-pipeline\\Trainer\\.system\\stateful_working_dir\\20240720-154120.432064', tmp_dir='output\\annisams11-pipeline\\Trainer\\.system\\executor_execution\\16\\.temp\\', pipeline_node=node_info {
#   type {
#     name: "tfx.components.trainer.component.Trainer"
#     base_type: TRAIN
#   }
#   id: "Trainer"
# }
# contexts {
#   contexts {
#     type {
#       name: "pipeline"
#     }
#     name {
#       field_value {
#         string_value: "annisams11-pipeline"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "pipeline_run"
#     }
#     name {
#       field_value {
#         string_value: "20240720-154120.432064"
#       }
#     }
#   }
#   contexts {
#     type {
#       name: "node"
#     }
#     name {
#       field_value {
#         string_value: "annisams11-pipeline.Trainer"
#       }
#     }
#   }
# }
# inputs {
#   inputs {
#     key: "examples"
#     value {
#       channels {
#         producer_node_query {
#           id: "Transform"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "annisams11-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20240720-154120.432064"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "annisams11-pipeline.Transform"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "Examples"
#             base_type: DATASET
#           }
#         }
#         output_key: "transformed_examples"
#       }
#       min_count: 1
#     }
#   }
#   inputs {
#     key: "hyperparameters"
#     value {
#       channels {
#         producer_node_query {
#           id: "Tuner"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "annisams11-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20240720-154120.432064"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "annisams11-pipeline.Tuner"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "HyperParameters"
#           }
#         }
#         output_key: "best_hyperparameters"
#       }
#     }
#   }
#   inputs {
#     key: "schema"
#     value {
#       channels {
#         producer_node_query {
#           id: "SchemaGen"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "annisams11-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20240720-154120.432064"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "annisams11-pipeline.SchemaGen"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "Schema"
#           }
#         }
#         output_key: "schema"
#       }
#     }
#   }
#   inputs {
#     key: "transform_graph"
#     value {
#       channels {
#         producer_node_query {
#           id: "Transform"
#         }
#         context_queries {
#           type {
#             name: "pipeline"
#           }
#           name {
#             field_value {
#               string_value: "annisams11-pipeline"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "pipeline_run"
#           }
#           name {
#             field_value {
#               string_value: "20240720-154120.432064"
#             }
#           }
#         }
#         context_queries {
#           type {
#             name: "node"
#           }
#           name {
#             field_value {
#               string_value: "annisams11-pipeline.Transform"
#             }
#           }
#         }
#         artifact_query {
#           type {
#             name: "TransformGraph"
#           }
#         }
#         output_key: "transform_graph"
#       }
#     }
#   }
# }
# outputs {
#   outputs {
#     key: "model"
#     value {
#       artifact_spec {
#         type {
#           name: "Model"
#           base_type: MODEL
#         }
#       }
#     }
#   }
#   outputs {
#     key: "model_run"
#     value {
#       artifact_spec {
#         type {
#           name: "ModelRun"
#         }
#       }
#     }
#   }
# }
# parameters {
#   parameters {
#     key: "custom_config"
#     value {
#       field_value {
#         string_value: "null"
#       }
#     }
#   }
#   parameters {
#     key: "eval_args"
#     value {
#       field_value {
#         string_value: "{\n  \"num_steps\": 1000,\n  \"splits\": [\n    \"eval\"\n  ]\n}"
#       }
#     }
#   }
#   parameters {
#     key: "module_path"
#     value {
#       field_value {
#         string_value: "stroke_pred_trainer@output\\annisams11-pipeline\\_wheels\\tfx_user_code_Trainer-0.0+c9842627d14a7260429e87a5ee0bbb6a28ca35a48a05d0344e6aa6eeb4a3cc2f-py3-none-any.whl"
#       }
#     }
#   }
#   parameters {
#     key: "train_args"
#     value {
#       field_value {
#         string_value: "{\n  \"num_steps\": 5000,\n  \"splits\": [\n    \"train\"\n  ]\n}"
#       }
#     }
#   }
# }
# upstream_nodes: "SchemaGen"
# upstream_nodes: "Transform"
# upstream_nodes: "Tuner"
# downstream_nodes: "Evaluator"
# downstream_nodes: "Pusher"
# execution_options {
#   caching_options {
#     enable_cache: true
#   }
# }
# , pipeline_info=id: "annisams11-pipeline"
# , pipeline_run_id='20240720-154120.432064')
# WARNING:absl:Examples artifact does not have payload_format custom property. Falling back to FORMAT_TF_EXAMPLE
# WARNING:absl:Examples artifact does not have payload_format custom property. Falling back to FORMAT_TF_EXAMPLE
# WARNING:absl:Examples artifact does not have payload_format custom property. Falling back to FORMAT_TF_EXAMPLE
# INFO:absl:udf_utils.get_fn {'custom_config': 'null', 'eval_args': '{\n  "num_steps": 1000,\n  "splits": [\n    "eval"\n  ]\n}', 'train_args': '{\n  "num_steps": 5000,\n  "splits": [\n    "train"\n  ]\n}', 'module_path': 'stroke_pred_trainer@output\\annisams11-pipeline\\_wheels\\tfx_user_code_Trainer-0.0+c9842627d14a7260429e87a5ee0bbb6a28ca35a48a05d0344e6aa6eeb4a3cc2f-py3-none-any.whl'} 'run_fn'
# INFO:absl:Installing 'output\\annisams11-pipeline\\_wheels\\tfx_user_code_Trainer-0.0+c9842627d14a7260429e87a5ee0bbb6a28ca35a48a05d0344e6aa6eeb4a3cc2f-py3-none-any.whl' to a temporary directory.
# INFO:absl:Executing: ['c:\\Users\\ANNISA MUFIDATUN S\\anaconda3\\envs\\a443-churn\\python.exe', '-m', 'pip', 'install', '--target', 'C:\\Users\\ANNISA~1\\AppData\\Local\\Temp\\tmpe8xchrbx', 'output\\annisams11-pipeline\\_wheels\\tfx_user_code_Trainer-0.0+c9842627d14a7260429e87a5ee0bbb6a28ca35a48a05d0344e6aa6eeb4a3cc2f-py3-none-any.whl']
# INFO:absl:Successfully installed 'output\\annisams11-pipeline\\_wheels\\tfx_user_code_Trainer-0.0+c9842627d14a7260429e87a5ee0bbb6a28ca35a48a05d0344e6aa6eeb4a3cc2f-py3-none-any.whl'.
# INFO:absl:MetadataStore with DB connection initialized
# ERROR:absl:Execution 16 failed.
# INFO:absl:Cleaning up stateless execution info.
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# c:\Users\ANNISA MUFIDATUN S\anaconda3\envs\a443-churn\lib\site-packages\tfx\utils\import_utils.py in import_func_from_module(module_path, fn_name)
#      59   try:
# ---> 60     user_module = importlib.import_module(module_path)
#      61   except ImportError as e:
#
# c:\Users\ANNISA MUFIDATUN S\anaconda3\envs\a443-churn\lib\importlib\__init__.py in import_module(name, package)
#     126             level += 1
# --> 127     return _bootstrap._gcd_import(name[level:], package, level)
#     128
#
# c:\Users\ANNISA MUFIDATUN S\anaconda3\envs\a443-churn\lib\importlib\_bootstrap.py in _gcd_import(name, package, level)
#
# c:\Users\ANNISA MUFIDATUN S\anaconda3\envs\a443-churn\lib\importlib\_bootstrap.py in _find_and_load(name, import_)
#
# c:\Users\ANNISA MUFIDATUN S\anaconda3\envs\a443-churn\lib\importlib\_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# c:\Users\ANNISA MUFIDATUN S\anaconda3\envs\a443-churn\lib\importlib\_bootstrap.py in _load_unlocked(spec)
#
# c:\Users\ANNISA MUFIDATUN S\anaconda3\envs\a443-churn\lib\importlib\_bootstrap_external.py in exec_module(self, module)
#
# c:\Users\ANNISA MUFIDATUN S\anaconda3\envs\a443-churn\lib\importlib\_bootstrap.py in _call_with_frames_removed(f, *args, **kwds)
#
# C:\Users\ANNISA~1\AppData\Local\Temp\tmpe8xchrbx\stroke_pred_trainer.py in <module>
#      17 )
# ---> 18 from stroke_pred_tuner import input_fn
#      19
#
# ImportError: cannot import name 'input_fn' from 'stroke_pred_tuner' (C:\Users\ANNISA~1\AppData\Local\Temp\tmpuwttqnpz\stroke_pred_tuner.py)
#
# The above exception was the direct cause of the following exception:
#
# ImportError                               Traceback (most recent call last)
# c:\Users\ANNISA MUFIDATUN S\anaconda3\envs\a443-churn\lib\site-packages\apache_beam\runners\common.cp39-win_amd64.pyd in apache_beam.runners.common.DoFnRunner.process()
#
# c:\Users\ANNISA MUFIDATUN S\anaconda3\envs\a443-churn\lib\site-packages\apache_beam\runners\common.cp39-win_amd64.pyd in apache_beam.runners.common.PerWindowInvoker.invoke_process()
#
# c:\Users\ANNISA MUFIDATUN S\anaconda3\envs\a443-churn\lib\site-packages\apache_beam\runners\common.cp39-win_amd64.pyd in apache_beam.runners.common.PerWindowInvoker._invoke_process_per_window()
#
# c:\Users\ANNISA MUFIDATUN S\anaconda3\envs\a443-churn\lib\site-packages\tfx\orchestration\beam\beam_dag_runner.py in process(self, element, *signals)
#      89     logging.info('node %s is running.', self._node_id)
# ---> 90     self._run_node()
#      91     logging.info('node %s is finished.', self._node_id)
#
# c:\Users\ANNISA MUFIDATUN S\anaconda3\envs\a443-churn\lib\site-packages\tfx\orchestration\beam\beam_dag_runner.py in _run_node(self)
#      98         partial_run_utils.snapshot(mlmd_handle, self._pipeline)
# ---> 99     launcher.Launcher(
#     100         pipeline_node=self._pipeline_node,
#
# c:\Users\ANNISA MUFIDATUN S\anaconda3\envs\a443-churn\lib\site-packages\tfx\orchestration\portable\launcher.py in launch(self)
#     572           executor_watcher.start()
# --> 573         executor_output = self._run_executor(execution_info)
#     574       except Exception as e:  # pylint: disable=broad-except
#
# c:\Users\ANNISA MUFIDATUN S\anaconda3\envs\a443-churn\lib\site-packages\tfx\orchestration\portable\launcher.py in _run_executor(self, execution_info)
#     447     try:
# --> 448       executor_output = self._executor_operator.run_executor(execution_info)
#     449       code = executor_output.execution_result.code
#
# c:\Users\ANNISA MUFIDATUN S\anaconda3\envs\a443-churn\lib\site-packages\tfx\orchestration\portable\python_executor_operator.py in run_executor(self, execution_info)
#     134     executor = self._executor_cls(context=context)
# --> 135     return run_with_executor(execution_info, executor)
#
# c:\Users\ANNISA MUFIDATUN S\anaconda3\envs\a443-churn\lib\site-packages\tfx\orchestration\portable\python_executor_operator.py in run_with_executor(execution_info, executor)
#      57   output_dict = copy.deepcopy(execution_info.output_dict)
# ---> 58   result = executor.Do(execution_info.input_dict, output_dict,
#      59                        execution_info.exec_properties)
#
# c:\Users\ANNISA MUFIDATUN S\anaconda3\envs\a443-churn\lib\site-packages\tfx\components\trainer\executor.py in Do(self, input_dict, output_dict, exec_properties)
#     173     fn_args = self._GetFnArgs(input_dict, output_dict, exec_properties)
# --> 174     run_fn = udf_utils.get_fn(exec_properties, 'run_fn')
#     175
#
# c:\Users\ANNISA MUFIDATUN S\anaconda3\envs\a443-churn\lib\site-packages\tfx\components\util\udf_utils.py in get_fn(exec_properties, fn_name)
#      55     module_path = exec_properties[_MODULE_PATH_KEY]
# ---> 56     return import_utils.import_func_from_module(module_path, fn_name)
#      57   elif has_module_file:
#
# c:\Users\ANNISA MUFIDATUN S\anaconda3\envs\a443-churn\lib\site-packages\tfx\utils\import_utils.py in import_func_from_module(module_path, fn_name)
#      61   except ImportError as e:
# ---> 62     raise ImportError('Could not import requested module path %r.' %
#      63                       original_module_path) from e
#
# ImportError: Could not import requested module path 'stroke_pred_trainer@output\\annisams11-pipeline\\_wheels\\tfx_user_code_Trainer-0.0+c9842627d14a7260429e87a5ee0bbb6a28ca35a48a05d0344e6aa6eeb4a3cc2f-py3-none-any.whl'.
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_28876\3369058399.py in <cell line: 46>()
#      44
#      45 pipeline = init_local_pipeline(components, pipeline_root)
# ---> 46 BeamDagRunner().run(pipeline=pipeline)
#
# c:\Users\ANNISA MUFIDATUN S\anaconda3\envs\a443-churn\lib\site-packages\tfx\orchestration\portable\tfx_runner.py in run(self, pipeline, run_options, **kwargs)
#     122     else:
#     123       run_options_pb = None
# --> 124     return self.run_with_ir(pipeline_pb, run_options=run_options_pb, **kwargs)
#
# c:\Users\ANNISA MUFIDATUN S\anaconda3\envs\a443-churn\lib\site-packages\tfx\orchestration\beam\beam_dag_runner.py in run_with_ir(self, pipeline, run_options)
#     295                       pipeline=pipeline),
#     296                   *[beam.pvalue.AsIter(s) for s in signals_to_wait]))
# --> 297           logging.info('Node %s is scheduled.', node_id)
#
# c:\Users\ANNISA MUFIDATUN S\anaconda3\envs\a443-churn\lib\site-packages\apache_beam\pipeline.py in __exit__(self, exc_type, exc_val, exc_tb)
#     598     try:
#     599       if not exc_type:
# --> 600         self.result = self.run()
#     601         self.result.wait_until_finish()
#     602     finally:
#
# c:\Users\ANNISA MUFIDATUN S\anaconda3\envs\a443-churn\lib\site-packages\apache_beam\pipeline.py in run(self, test_runner_api)
#     575         finally:
#     576           shutil.rmtree(tmpdir)
# --> 577       return self.runner.run_pipeline(self, self._options)
#     578     finally:
#     579       if not is_in_ipython():
#
# c:\Users\ANNISA MUFIDATUN S\anaconda3\envs\a443-churn\lib\site-packages\apache_beam\runners\direct\direct_runner.py in run_pipeline(self, pipeline, options)
#     129       runner = BundleBasedDirectRunner()
#     130
# --> 131     return runner.run_pipeline(pipeline, options)
#     132
#     133
#
# c:\Users\ANNISA MUFIDATUN S\anaconda3\envs\a443-churn\lib\site-packages\apache_beam\runners\portability\fn_api_runner\fn_runner.py in run_pipeline(self, pipeline, options)
#     199         options.view_as(pipeline_options.ProfilingOptions))
#     200
# --> 201     self._latest_run_result = self.run_via_runner_api(
#     202         pipeline.to_runner_api(default_environment=self._default_environment),
#     203         options)
#
# c:\Users\ANNISA MUFIDATUN S\anaconda3\envs\a443-churn\lib\site-packages\apache_beam\runners\portability\fn_api_runner\fn_runner.py in run_via_runner_api(self, pipeline_proto, options)
#     220       pipeline_proto = self.embed_default_docker_image(pipeline_proto)
#     221     stage_context, stages = self.create_stages(pipeline_proto)
# --> 222     return self.run_stages(stage_context, stages)
#     223
#     224   def embed_default_docker_image(self, pipeline_proto):
#
# c:\Users\ANNISA MUFIDATUN S\anaconda3\envs\a443-churn\lib\site-packages\apache_beam\runners\portability\fn_api_runner\fn_runner.py in run_stages(self, stage_context, stages)
#     451
#     452           bundle_counter += 1
# --> 453           bundle_results = self._execute_bundle(
#     454               runner_execution_context, bundle_context_manager, bundle_input)
#     455
#
# c:\Users\ANNISA MUFIDATUN S\anaconda3\envs\a443-churn\lib\site-packages\apache_beam\runners\portability\fn_api_runner\fn_runner.py in _execute_bundle(self, runner_execution_context, bundle_context_manager, bundle_input)
#     779
#     780     last_result, deferred_inputs, newly_set_timers, watermark_updates = (
# --> 781         self._run_bundle(
#     782             runner_execution_context,
#     783             bundle_context_manager,
#
# c:\Users\ANNISA MUFIDATUN S\anaconda3\envs\a443-churn\lib\site-packages\apache_beam\runners\portability\fn_api_runner\fn_runner.py in _run_bundle(self, runner_execution_context, bundle_context_manager, bundle_input, data_output, expected_timer_output, bundle_manager)
#    1008         expected_timer_output)
#    1009
# -> 1010     result, splits = bundle_manager.process_bundle(
#    1011         data_input, data_output, input_timers, expected_timer_output)
#    1012     # Now we collect all the deferred inputs remaining from bundle execution.
#
# c:\Users\ANNISA MUFIDATUN S\anaconda3\envs\a443-churn\lib\site-packages\apache_beam\runners\portability\fn_api_runner\fn_runner.py in process_bundle(self, inputs, expected_outputs, fired_timers, expected_output_timers, dry_run)
#    1344             process_bundle_descriptor.id,
#    1345             cache_tokens=[next(self._cache_token_generator)]))
# -> 1346     result_future = self._worker_handler.control_conn.push(process_bundle_req)
#    1347
#    1348     split_results = []  # type: List[beam_fn_api_pb2.ProcessBundleSplitResponse]
#
# c:\Users\ANNISA MUFIDATUN S\anaconda3\envs\a443-churn\lib\site-packages\apache_beam\runners\portability\fn_api_runner\worker_handlers.py in push(self, request)
#     377       self._uid_counter += 1
#     378       request.instruction_id = 'control_%s' % self._uid_counter
# --> 379     response = self.worker.do_instruction(request)
#     380     return ControlFuture(request.instruction_id, response)
#     381
#
# c:\Users\ANNISA MUFIDATUN S\anaconda3\envs\a443-churn\lib\site-packages\apache_beam\runners\worker\sdk_worker.py in do_instruction(self, request)
#     594     if request_type:
#     595       # E.g. if register is set, this will call self.register(request.register))
# --> 596       return getattr(self, request_type)(
#     597           getattr(request, request_type), request.instruction_id)
#     598     else:
#
# c:\Users\ANNISA MUFIDATUN S\anaconda3\envs\a443-churn\lib\site-packages\apache_beam\runners\worker\sdk_worker.py in process_bundle(self, request, instruction_id)
#     632         with self.maybe_profile(instruction_id):
#     633           delayed_applications, requests_finalization = (
# --> 634               bundle_processor.process_bundle(instruction_id))
#     635           monitoring_infos = bundle_processor.monitoring_infos()
#     636           response = beam_fn_api_pb2.InstructionResponse(
#
# c:\Users\ANNISA MUFIDATUN S\anaconda3\envs\a443-churn\lib\site-packages\apache_beam\runners\worker\bundle_processor.py in process_bundle(self, instruction_id)
#    1001                   element.timer_family_id, timer_data)
#    1002           elif isinstance(element, beam_fn_api_pb2.Elements.Data):
# -> 1003             input_op_by_transform_id[element.transform_id].process_encoded(
#    1004                 element.data)
#    1005
#
# c:\Users\ANNISA MUFIDATUN S\anaconda3\envs\a443-churn\lib\site-packages\apache_beam\runners\worker\bundle_processor.py in process_encoded(self, encoded_windowed_values)
#     225       decoded_value = self.windowed_coder_impl.decode_from_stream(
#     226           input_stream, True)
# --> 227       self.output(decoded_value)
#     228
#     229   def monitoring_infos(self, transform_id, tag_to_pcollection_id):
#
# c:\Users\ANNISA MUFIDATUN S\anaconda3\envs\a443-churn\lib\site-packages\apache_beam\runners\worker\operations.cp39-win_amd64.pyd in apache_beam.runners.worker.operations.Operation.output()
#
# c:\Users\ANNISA MUFIDATUN S\anaconda3\envs\a443-churn\lib\site-packages\apache_beam\runners\worker\operations.cp39-win_amd64.pyd in apache_beam.runners.worker.operations.Operation.output()
#
# c:\Users\ANNISA MUFIDATUN S\anaconda3\envs\a443-churn\lib\site-packages\apache_beam\runners\worker\operations.cp39-win_amd64.pyd in apache_beam.runners.worker.operations.SingletonElementConsumerSet.receive()
#
# c:\Users\ANNISA MUFIDATUN S\anaconda3\envs\a443-churn\lib\site-packages\apache_beam\runners\worker\operations.cp39-win_amd64.pyd in apache_beam.runners.worker.operations.SingletonElementConsumerSet.receive()
#
# c:\Users\ANNISA MUFIDATUN S\anaconda3\envs\a443-churn\lib\site-packages\apache_beam\runners\worker\operations.cp39-win_amd64.pyd in apache_beam.runners.worker.operations.DoOperation.process()
#
# c:\Users\ANNISA MUFIDATUN S\anaconda3\envs\a443-churn\lib\site-packages\apache_beam\runners\worker\operations.cp39-win_amd64.pyd in apache_beam.runners.worker.operations.DoOperation.process()
#
# c:\Users\ANNISA MUFIDATUN S\anaconda3\envs\a443-churn\lib\site-packages\apache_beam\runners\common.cp39-win_amd64.pyd in apache_beam.runners.common.DoFnRunner.process()
#
# c:\Users\ANNISA MUFIDATUN S\anaconda3\envs\a443-churn\lib\site-packages\apache_beam\runners\common.cp39-win_amd64.pyd in apache_beam.runners.common.DoFnRunner._reraise_augmented()
#
# c:\Users\ANNISA MUFIDATUN S\anaconda3\envs\a443-churn\lib\site-packages\apache_beam\runners\common.cp39-win_amd64.pyd in apache_beam.runners.common.DoFnRunner.process()
#
# c:\Users\ANNISA MUFIDATUN S\anaconda3\envs\a443-churn\lib\site-packages\apache_beam\runners\common.cp39-win_amd64.pyd in apache_beam.runners.common.PerWindowInvoker.invoke_process()
#
# c:\Users\ANNISA MUFIDATUN S\anaconda3\envs\a443-churn\lib\site-packages\apache_beam\runners\common.cp39-win_amd64.pyd in apache_beam.runners.common.PerWindowInvoker._invoke_process_per_window()
#
# c:\Users\ANNISA MUFIDATUN S\anaconda3\envs\a443-churn\lib\site-packages\tfx\orchestration\beam\beam_dag_runner.py in process(self, element, *signals)
#      88
#      89     logging.info('node %s is running.', self._node_id)
# ---> 90     self._run_node()
#      91     logging.info('node %s is finished.', self._node_id)
#      92
#
# c:\Users\ANNISA MUFIDATUN S\anaconda3\envs\a443-churn\lib\site-packages\tfx\orchestration\beam\beam_dag_runner.py in _run_node(self)
#      97       with metadata.Metadata(self._mlmd_connection_config) as mlmd_handle:
#      98         partial_run_utils.snapshot(mlmd_handle, self._pipeline)
# ---> 99     launcher.Launcher(
#     100         pipeline_node=self._pipeline_node,
#     101         mlmd_connection=metadata.Metadata(self._mlmd_connection_config),
#
# c:\Users\ANNISA MUFIDATUN S\anaconda3\envs\a443-churn\lib\site-packages\tfx\orchestration\portable\launcher.py in launch(self)
#     571               executor_watcher.address)
#     572           executor_watcher.start()
# --> 573         executor_output = self._run_executor(execution_info)
#     574       except Exception as e:  # pylint: disable=broad-except
#     575         execution_output = (
#
# c:\Users\ANNISA MUFIDATUN S\anaconda3\envs\a443-churn\lib\site-packages\tfx\orchestration\portable\launcher.py in _run_executor(self, execution_info)
#     446     outputs_utils.make_output_dirs(execution_info.output_dict)
#     447     try:
# --> 448       executor_output = self._executor_operator.run_executor(execution_info)
#     449       code = executor_output.execution_result.code
#     450       if code != 0:
#
# c:\Users\ANNISA MUFIDATUN S\anaconda3\envs\a443-churn\lib\site-packages\tfx\orchestration\portable\python_executor_operator.py in run_executor(self, execution_info)
#     133         pipeline_run_id=execution_info.pipeline_run_id)
#     134     executor = self._executor_cls(context=context)
# --> 135     return run_with_executor(execution_info, executor)
#
# c:\Users\ANNISA MUFIDATUN S\anaconda3\envs\a443-churn\lib\site-packages\tfx\orchestration\portable\python_executor_operator.py in run_with_executor(execution_info, executor)
#      56
#      57   output_dict = copy.deepcopy(execution_info.output_dict)
# ---> 58   result = executor.Do(execution_info.input_dict, output_dict,
#      59                        execution_info.exec_properties)
#      60   if not result:
#
# c:\Users\ANNISA MUFIDATUN S\anaconda3\envs\a443-churn\lib\site-packages\tfx\components\trainer\executor.py in Do(self, input_dict, output_dict, exec_properties)
#     172
#     173     fn_args = self._GetFnArgs(input_dict, output_dict, exec_properties)
# --> 174     run_fn = udf_utils.get_fn(exec_properties, 'run_fn')
#     175
#     176     # Train the model
#
# c:\Users\ANNISA MUFIDATUN S\anaconda3\envs\a443-churn\lib\site-packages\tfx\components\util\udf_utils.py in get_fn(exec_properties, fn_name)
#      54   if has_module_path:
#      55     module_path = exec_properties[_MODULE_PATH_KEY]
# ---> 56     return import_utils.import_func_from_module(module_path, fn_name)
#      57   elif has_module_file:
#      58     if has_fn:
#
# c:\Users\ANNISA MUFIDATUN S\anaconda3\envs\a443-churn\lib\site-packages\tfx\utils\import_utils.py in import_func_from_module(module_path, fn_name)
#      60     user_module = importlib.import_module(module_path)
#      61   except ImportError as e:
# ---> 62     raise ImportError('Could not import requested module path %r.' %
#      63                       original_module_path) from e
#      64   # Restore original sys.path.
#
# ImportError: Could not import requested module path 'stroke_pred_trainer@output\\annisams11-pipeline\\_wheels\\tfx_user_code_Trainer-0.0+c9842627d14a7260429e87a5ee0bbb6a28ca35a48a05d0344e6aa6eeb4a3cc2f-py3-none-any.whl'. [while running 'Run[Trainer]']

# %%
# def init_local_pipeline(
#     components, pipeline_root: Text
# ) -> pipeline.Pipeline:
#     logging.info(f"Pipeline root set to: {pipeline_root}")
#     beam_args = [
#         "--direct_running_mode=multi_processing"
#         # 0 auto-detect based on on the number of CPUs available
#         # during execution time.
#         "----direct_num_workers=0" 
#     ]

#     return pipeline.Pipeline(
#         pipeline_name=PIPELINE_NAME,
#         pipeline_root=pipeline_root,
#         components=components,
#         enable_cache=True,
#         metadata_connection_config=metadata.sqlite_metadata_connection_config(
#             metadata_path
#         ),
#         eam_pipeline_args=beam_args
#     )

# if __name__ == "__main__":
#     logging.set_verbosity(logging.INFO)

#     from modules.components import init_components

#     components = init_components(
#         DATA_ROOT,
#         transform_module=TRANSFORM_MODULE_FILE,
#         tuner_module=TUNER_MODULE_FILE,
#         training_module=TRAINER_MODULE_FILE,
#         training_steps=5000,
#         eval_steps=1000,
#         serving_model_dir=serving_model_dir,
#     )

#     pipeline = init_local_pipeline(components, pipeline_root)
#     BeamDagRunner().run(pipeline=pipeline)
